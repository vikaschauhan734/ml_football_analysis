# %% [markdown]
# ### This is Google Colab notebook.

# %%
# !pip install ultralytics
# !pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 896.3/896.3 kB 34.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 kB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="sp3LnxeA9ckQFE3WPBW6")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to football-players-detection-1 in yolov11:: 100%|██████████| 1338/1338 [00:00<00:00, 1754.32it/s]

# %% [markdown]
# #### Uploaded yolo11n.pt to session storage

# %%
# !yolo task=detect mode=train model=yolo11n.pt data={dataset.location}/data.yaml epochs = 100 imgsz=640
# Out:
# Ultralytics 8.3.37 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
rf = Roboflow(api_key="sp3LnxeA9ckQFE3WPBW6")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %% [markdown]
# ### Uploaded yolov5n.pt to session storage

# %%
# !yolo task=detect mode=train model=yolov5n.pt data={dataset.location}/data.yaml epochs = 100 imgsz=640
# Out:
# PRO TIP 💡 Replace 'model=yolov5n.pt' with new 'model=yolov5nu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# ...
# 100% 5.31M/5.31M [00:00<00:00, 303MB/s]
# Ultralytics 8.3.37 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# ### Uploaded yolov5l.pt to session storage

# %%
# !yolo task=detect mode=train model=yolov5l.pt data={dataset.location}/data.yaml epochs = 100 imgsz=640
# Out:
# PRO TIP 💡 Replace 'model=yolov5l.pt' with new 'model=yolov5lu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# ...
# 100% 102M/102M [00:03<00:00, 27.0MB/s]
# Ultralytics 8.3.37 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# ### Uploaded yolo11l.pt to session storage

# %%
# !yolo task=detect mode=train model=yolo11l.pt data={dataset.location}/data.yaml epochs = 100 imgsz=640
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.38 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
